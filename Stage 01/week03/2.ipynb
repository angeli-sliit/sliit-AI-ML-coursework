# %%
import pandas as pd
url = "https://raw.githubusercontent.com/COVID19-Malta/COVID19-Data/refs/heads/master/COVID-19%20Malta%20-%20Aggregate%20Data%20Set.csv"
pf=pd.read_csv(url)
pf.head(10)
# Out:
#   Covering dates & Week Number        Date  New Cases  Total Cases  Recovered  \
# 0                          NaN  06/03/2020          1            1          0
# 1                          NaN  07/03/2020          2            3          0
# 2                          NaN  08/03/2020          0            3          0
# 3                          NaN  09/03/2020          1            4          0
# 4                          NaN  10/03/2020          1            5          0
# 5                          NaN  11/03/2020          2            7          0
# 6                          NaN  12/03/2020          5           12          0
# 7                          NaN  13/03/2020          1           13          1
# 8                          NaN  14/03/2020          5           18          1
# 9                          NaN  15/03/2020          3           21          2
#
#    Deaths  Active Cases
# 0       0             1
# 1       0             3
# 2       0             3
# ...
